# %%
# !pip install datasets
from datasets import load_dataset
ds = load_dataset("Manith/ConveyorBelt")

# %%
# !unzip -q /content/exp4.zip -d /content/

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# !python train_val_split.py --datapath="/content/exp4" --train_pct=0.9
# Out:
# --2025-04-05 17:46:24--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2025-04-05 17:46:24 (56.7 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Number of image files: 119
# Number of annotation files: 118
# Images moving to train: 107
# Images moving to validation: 12

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.6 MB/s eta 0:00:00

# %%
# !yolo detect train data=data.yaml model=yolo11s.pt epochs=80 imgsz=640 batch=16 name=yolo11s_run
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/yolo11s_run3/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.20.jpeg: 480x640 1 S, 75.0ms
# image 2/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.27.jpeg: 480x640 1 M, 12.5ms
# image 3/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.28.jpeg: 480x640 1 L, 12.5ms
# image 4/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.30.jpeg: 480x640 1 S, 12.5ms
# image 5/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.34.jpeg: 480x640 1 S, 12.5ms
# image 6/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.35 (1).jpeg: 480x640 1 Xs, 12.5ms
# image 7/23 /content/data/validation/images/WhatsApp Image 2025-04-02 at 20.46.37 (1).jpeg: 480x640 1 S, 12.5ms
# ...
